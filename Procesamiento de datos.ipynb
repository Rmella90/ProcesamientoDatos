# %%
import numpy as np 
# NumPy is for mathematical operations, enabling efficient array processing in Python.
# Numpy es para operaciones matemáticas, permite un procesamiento eficiente en matrices. 

import pandas as pd 
# Pandas is for data manipulation and analysis, offering versatile data structures like DataFrames, ideal for data
#  cleaning and exploration.
# Pandas es para manipulación y analisis de datos, ofrece estructuras versátiles como los los marcos de datos 
# (dataframes/DF), ideales para la limpieza y exploración de datos.

# %%
# Read a CSV file into a Pandas DataFrame
# Lee un archivo CSV en un marco de datos de Pandas. 
df= pd.read_csv("Ditry Data Sample1.csv")

# %%
#In Pandas displays the first few rows of a DataFrame, allowing quick inspection of its data.
#En Pandas muestra las primeras filas de un DataFrame, permitiendonos una rápida inspección de los datos.  
df.head()
# Out:
#         Segment>>     Consumer Unnamed: 2    Unnamed: 3      Unnamed: 4  \
# 0     Ship Mode>>  First Class   Same Day  Second Class  Standard Class
# 1        Order ID          NaN        NaN           NaN             NaN
# 2  CA-2011-100293          NaN        NaN           NaN             NaN
# 3  CA-2011-100706          NaN        NaN        129,44             NaN
# 4  CA-2011-100895          NaN        NaN           NaN          605,47
#
#   Consumer Total    Corporate Unnamed: 7    Unnamed: 8      Unnamed: 9  \
# 0            NaN  First Class   Same Day  Second Class  Standard Class
# 1            NaN          NaN        NaN           NaN             NaN
# 2            NaN          NaN        NaN           NaN             NaN
# 3         129,44          NaN        NaN           NaN             NaN
# 4         605,47          NaN        NaN           NaN             NaN
#
#   Corporate Total  Home Office Unnamed: 12   Unnamed: 13     Unnamed: 14  \
# ...

# %%
#In pandas displays the last few rows of a DataFrame, useful for inspecting the end of the data.
#En pandas muestra algunas de las últimas filas de un DataFrame, útil para inspeccionar el final de la data. 
df.tail()
# Out:
#           Segment>>   Consumer Unnamed: 2  Unnamed: 3   Unnamed: 4  \
# 820  US-2014-166611        NaN        NaN         NaN          NaN
# 821  US-2014-167920        NaN        NaN     1827,51          NaN
# 822  US-2014-168116        NaN        NaN         NaN          NaN
# 823  US-2014-168690        NaN        NaN         NaN        2,808
# 824     Grand Total  20802,173   8132,409  49724,2545  116922,1345
#
#     Consumer Total  Corporate Unnamed: 7 Unnamed: 8  Unnamed: 9  \
# 820            NaN        NaN        NaN        NaN      68,742
# 821        1827,51        NaN        NaN        NaN         NaN
# 822            NaN        NaN    8167,42        NaN         NaN
# 823          2,808        NaN        NaN        NaN         NaN
# 824     195580,971  20792,607   9907,308  35243,231  55942,7865
#
#     Corporate Total Home Office Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 820          68,742         NaN         NaN         NaN         NaN
# ...

# %%
# In pandas provides a concise summary of a DataFrame's structure, including data types, non-null counts, 
# and memory usage.
# En pandas proporciona un resumen consiso de la estructura de un DataFrane, incluyendo los tipos de datos, 
# cuenta los datos nulos, y uso de la memoria.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Segment>>          825 non-null    object
#  1   Consumer           74 non-null     object
#  2   Unnamed: 2         30 non-null     object
#  3   Unnamed: 3         93 non-null     object
#  4   Unnamed: 4         255 non-null    object
#  5   Consumer Total     445 non-null    object
#  6   Corporate          42 non-null     object
#  7   Unnamed: 7         7 non-null      object
#  8   Unnamed: 8         52 non-null     object
#  9   Unnamed: 9         154 non-null    object
#  10  Corporate Total    248 non-null    object
#  11  Home Office        14 non-null     object
#  12  Unnamed: 12        8 non-null      object
#  13  Unnamed: 13        25 non-null     object
#  14  Unnamed: 14        92 non-null     object
#  15  Home Office Total  132 non-null    object
# ...

# %%
"""Note: First impression of the data set is that it is messed up, the data seems to be in random rows and columns, 
we don't have proper column names, it could have 2 row with column names, we have a summary row at the end, some positive 
things and I think They can be the bridges to clean and ordering the data is that the segment column has no nulls, 
and it looks like a primary key """


"""Nota: La primera impresión que deja el dataset es que esta desordenado, los datos parecen estar en filas y columnas
al azar, no tenemos nombres apropiados en las columnas, existen dos columnas que sugieren son nombres de campos
tenemos una fila de resumen al final, algunas cosas positivas y creo que pueden ser los puentes para limpiar y ordenar 
la data es que la columna segment no tiene nulos, y parece una clave primaria """
# Out:
# 'Nota: La primera impresión que deja el dataset es que esta desordenado, los datos parecen estar en filas y columnas\nal azar, no tenemos nombres apropiados en las columnas, existen dos columnas que sugieren son nombres de campos\ntenemos una fila de resumen al final, algunas cosas positivas y creo que pueden ser los puentes para limpiar y ordenar \nla data es que la columna segment no tiene nulos, y parece una clave primaria '

# %%
duplicados = df[df['Segment>>'].duplicated()]
num_duplicados = len(duplicados)
#Show the duplicate values and their quantities
# Mostrar los valores duplicados y su cantidad
print("Valores duplicados en 'Segment>>':")
print(duplicados)
print(f"Cantidad de valores duplicados: {num_duplicados}")

#With this code  i intend know how many duplicated values there are in the segment column,
#the result show me that there aren't duplicated values and with the higher observation 
# of the data I understand that it is only deranged.

#Con este código pretendo conocer cuantos valores duplicados hay en la columna Segment, 
#el resultado me desmuestra que no hay valores duplicados y con una mayor observación 
# de la data entiendo que solo esta desordenada.
# Out:
# Valores duplicados en 'Segment>>':
# Empty DataFrame
# Columns: [Segment>>, Consumer, Unnamed: 2, Unnamed: 3, Unnamed: 4, Consumer Total, Corporate, Unnamed: 7, Unnamed: 8, Unnamed: 9, Corporate Total, Home Office, Unnamed: 12, Unnamed: 13, Unnamed: 14, Home Office Total]
# Index: []
# Cantidad de valores duplicados: 0

# %%
valores_no_nulos_por_fila = df.count(axis=1)
print("Valores no nulos por fila:")
print(valores_no_nulos_por_fila)

#This function allow me to check how many values non-null there are per row, with this I Confirm that the data follows
# a pattern of 3 non-null per row, the data is out of order it is in a narrow format type with double indexing.

#Esta formula me permite revisar cuantos valores no nulos hay por fila, con esto confirmo que
#los datos sigue un patron de 3 no nulos por fila, la date sta desordenada esta en un tipo de formato angosto con doble
#indexsación.
# Out:
# Valores no nulos por fila:
# 0      13
# 1       1
# 2       3
# 3       3
# 4       3
#        ..
# 820     3
# 821     3
# 822     3
# 823     3
# 824    16
# Length: 825, dtype: int64

# %%
nombres_de_columnas = df.columns
print("Nombres de las columnas:")
print(nombres_de_columnas)

# I ask the names of columns to fix the actual names of columns
#Pido los nombres de las columnas para modificarlos
# Out:
# Nombres de las columnas:
# Index(['Segment>>', 'Consumer', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Consumer Total', 'Corporate', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Corporate Total', 'Home Office', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Home Office Total'],
#       dtype='object')

# %%
#As we understand the problem, we begin to work on ordering and eliminating the rows and columns that are not useful to us,
# and rename the columns.

#Como ya comprendimos el problema comenzamos a trabajar en reodernar y eliminar las filas que no nos son utiles,
# y cambiar el nombre de las columnas.

df = df.rename(columns={'Segment>>': 'Order Id', 'Consumer': 'First Class C', 'Unnamed: 2':'Same Day C',
                         'Unnamed: 3':'Second Class C','Unnamed: 4':'Standard Class C','Corporate': 'First Class P',
                         'Unnamed: 7': 'Same Day P', 'Unnamed: 8': 'Second Class P', 'Unnamed: 9': 'Standard Class P',
                         'Home Office':'First Class H', 'Unnamed: 12': 'Same Day H', 'Unnamed: 13': 'Second Class H',
                         'Unnamed: 14': 'Standard Class H'})

df = df.drop([0, 1, 824])

df.drop(columns=['Consumer Total', 'Corporate Total', 'Home Office Total'], axis=1, inplace=True)

df.head()
# Out:
#          Order Id First Class C Same Day C Second Class C Standard Class C  \
# 2  CA-2011-100293           NaN        NaN            NaN              NaN
# 3  CA-2011-100706           NaN        NaN         129,44              NaN
# 4  CA-2011-100895           NaN        NaN            NaN           605,47
# 5  CA-2011-100916           NaN        NaN            NaN              NaN
# 6  CA-2011-101266           NaN        NaN          13,36              NaN
#
#   First Class P Same Day P Second Class P Standard Class P First Class H  \
# 2           NaN        NaN            NaN              NaN           NaN
# 3           NaN        NaN            NaN              NaN           NaN
# 4           NaN        NaN            NaN              NaN           NaN
# 5           NaN        NaN            NaN           788,86           NaN
# 6           NaN        NaN            NaN              NaN           NaN
#
#   Same Day H Second Class H Standard Class H
# ...

# %%
df.tail()
# Out:
#            Order Id First Class C Same Day C Second Class C Standard Class C  \
# 819  US-2014-166233           NaN        NaN            NaN               24
# 820  US-2014-166611           NaN        NaN            NaN              NaN
# 821  US-2014-167920           NaN        NaN        1827,51              NaN
# 822  US-2014-168116           NaN        NaN            NaN              NaN
# 823  US-2014-168690           NaN        NaN            NaN            2,808
#
#     First Class P Same Day P Second Class P Standard Class P First Class H  \
# 819           NaN        NaN            NaN              NaN           NaN
# 820           NaN        NaN            NaN           68,742           NaN
# 821           NaN        NaN            NaN              NaN           NaN
# 822           NaN    8167,42            NaN              NaN           NaN
# 823           NaN        NaN            NaN              NaN           NaN
#
#     Same Day H Second Class H Standard Class H
# ...

# %%
df_FCC = df.dropna(subset=['First Class C'])
df_FCC = df_FCC[['Order Id', 'First Class C']]

df_SDC = df.dropna(subset=['Same Day C'])
df_SDC = df_SDC[['Order Id', 'Same Day C']]

df_SCC = df.dropna(subset=['Second Class C'])
df_SCC = df_SCC[['Order Id', 'Second Class C']]

df_STCC = df.dropna(subset=['Standard Class C'])
df_STCC = df_STCC[['Order Id', 'Standard Class C']]

#First I will manually work the entire Consumer segment, let's order the df by part with the data that
# are in each ship mode, generating df by type of flight with two columns.

#Primero trabajare de manera manual todo el segmento Consumer, ordemos el df por parte con los datos que 
# estan en cada tipo de vuelo, generando df por tipo de vuelo con dos columnas.

# %%
df_FCC.head()
# Out:
#           Order Id First Class C
# 13  CA-2011-103366        149,95
# 22  CA-2011-109043         243,6
# 31  CA-2011-113166         9,568
# 53  CA-2011-124023          8,96
# 65  CA-2011-130155          34,2

# %%
# Now we will generate two new columns, one called Ship Mode and the other Segment, in this way we extract the
# information that is in the data structure to a field, we will change the name of the columns again
# so that all the generated dfs have the same number and name of columns and finally we will update the indexes
# to be able to concatenate vertically without problem.


# Ahora generaremos dos columnas nuevas una que se llama Ship Mode y Segment, de esta forma extraemos la 
# información que esta en la estructura  de la data a un campo, cambiaremos nuevamente el nombre de las columnas 
# para que todos los df generados tenga el mismo número y nombre de columnas y por último actualizaremos los index 
# para poder concatenar de manera vertical sin problema.



df_FCC["Ship Mode"]= "First Class"
df_FCC["Segment"]= "Consumer"

df_SDC["Ship Mode"]= "Same Day"
df_SDC["Segment"]= "Consumer"

df_SCC["Ship Mode"]="Second Class"
df_SCC["Segment"]= "Consumer"

df_STCC["Ship Mode"]= "Standard Class"
df_STCC["Segment"]= "Consumer"

df_FCC = df_FCC.rename(columns={'First Class C': 'Order Cost'})

df_SDC = df_SDC.rename(columns={'Same Day C': 'Order Cost'})

df_SCC = df_SCC.rename(columns={'Second Class C': 'Order Cost'})

df_STCC = df_STCC.rename(columns={'Standard Class C': 'Order Cost'})


df_FCC = df_FCC.reset_index(drop=True)
df_SDC = df_SDC.reset_index(drop=True)
df_SCC = df_SCC.reset_index(drop=True)
df_STCC = df_STCC.reset_index(drop=True)

# %%
df_FCC.head()
# Out:
#          Order Id Order Cost    Ship Mode   Segment
# 0  CA-2011-103366     149,95  First Class  Consumer
# 1  CA-2011-109043      243,6  First Class  Consumer
# 2  CA-2011-113166      9,568  First Class  Consumer
# 3  CA-2011-124023       8,96  First Class  Consumer
# 4  CA-2011-130155       34,2  First Class  Consumer

# %%
df_SDC.head()
# Out:
#          Order Id Order Cost Ship Mode   Segment
# 0  CA-2011-113047      11,85  Same Day  Consumer
# 1  CA-2011-116239      354,9  Same Day  Consumer
# 2  CA-2011-130428   1142,165  Same Day  Consumer
# 3  CA-2011-131541    193,152  Same Day  Consumer
# 4  CA-2011-142951     23,472  Same Day  Consumer

# %%
df_SCC.head()
# Out:
#          Order Id Order Cost     Ship Mode   Segment
# 0  CA-2011-100706     129,44  Second Class  Consumer
# 1  CA-2011-101266      13,36  Second Class  Consumer
# 2  CA-2011-109232     545,94  Second Class  Consumer
# 3  CA-2011-110422     25,248  Second Class  Consumer
# 4  CA-2011-115357      62,91  Second Class  Consumer

# %%
df_STCC.head()
# Out:
#          Order Id Order Cost       Ship Mode   Segment
# 0  CA-2011-100895     605,47  Standard Class  Consumer
# 1  CA-2011-104283     616,14  Standard Class  Consumer
# 2  CA-2011-107573     23,472  Standard Class  Consumer
# 3  CA-2011-110100    302,376  Standard Class  Consumer
# 4  CA-2011-114335    337,088  Standard Class  Consumer

# %%
df_2 = pd.concat([df_FCC, df_SDC, df_SCC, df_STCC], axis=0, ignore_index=True)
df_2.head()

#I display the different DFs created with the new columns and column name changes
# to finally concatenate them vertically

#Visualizo los diferentes DF creados con las columnas nuevas y cambios de nombres de columnas
# para finalmente concatenarlas de manera vertical
# Out:
#          Order Id Order Cost    Ship Mode   Segment
# 0  CA-2011-103366     149,95  First Class  Consumer
# 1  CA-2011-109043      243,6  First Class  Consumer
# 2  CA-2011-113166      9,568  First Class  Consumer
# 3  CA-2011-124023       8,96  First Class  Consumer
# 4  CA-2011-130155       34,2  First Class  Consumer

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order Id    444 non-null    object
#  1   Order Cost  444 non-null    object
#  2   Ship Mode   444 non-null    object
#  3   Segment     444 non-null    object
# dtypes: object(4)
# memory usage: 14.0+ KB

# %%
df_2 = df_2.reset_index(drop=True)
df_2['Order Cost'] = df_2['Order Cost'].str.replace(',', '.')
df_2['Order Cost'] = df_2['Order Cost'].astype(float)
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order Id    444 non-null    object
#  1   Order Cost  444 non-null    float64
#  2   Ship Mode   444 non-null    object
#  3   Segment     444 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 14.0+ KB

# %%
print(df_2['Ship Mode'].unique())
# Out:
# ['First Class' 'Same Day' 'Second Class' 'Standard Class']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Make a plot using the seaborn and matplotlib libraries to show the order cost totals
# sorted by shipmode

# Hacemos un gráfico usando la librias seaborn y matplotlib para mostrar los totales de los order cost 
# ordenados por shipmode

# set the size of the chart
# Establecer el tamaño del gráfico
sns.set(rc={'figure.figsize': (12, 6)})

# Create the bar chart without filtering
# Crear el gráfico de barras sin necesidad de filtrar
grafico = sns.barplot(x='Ship Mode', y='Order Cost', data=df_2, estimator=sum)

# Graph Title
# Título del gráfico
grafico.set_title('Total por Categorías de Ship Mode')
# Show Graph
# Mostrar el gráfico
plt.show()

# %%
#Now the challenge is to generate a code that generates the cleaning of the entire dataframe without the need for manual work
# for each column
#Ahora el desafio es generar un código que genere la limpieza de todo el dataframe sin necesidad el trabajo manuamente
#  por cada columna

# %%
#We copy and adapt the methods used previously in an iteration function and filter the Order ID column


def generarDfLimpio(df): #Defino mi función
    dataframes = {}  # Genero un diccionario
    dataframe_names = []  # Lista para almacenar los nombres de los DataFrames
        
    i = 1

    for columna in df.columns:
        if columna != 'Order Id':  # Excluye la columna 'Order Id'
            df_temporal = df.dropna(subset=[columna])  # Eliminar filas con valores nulos en la columna actual
            df_temporal = df_temporal[['Order Id', columna]]  # Seleccionar solo las columnas 'Order Id' y la columna actual
            ultima_letra = columna[-1] #Tomo la última letra de cada columna (C, P o H)
            segment = {"C": "Consumer", "P": "Corporate", "H": "Home Office"}.get(ultima_letra, None) #Utilizo un diccionario para extraer el segmento de esa columna
            df_temporal["Segment"] = segment #Agrego ese segmento a toda la fila
            df_temporal["Ship Mode"] = columna[:-2] #Genero otra columna que es ship mode, donde agrego el nombre de la columna extrayendo los dos últimos caracteres
        
            df_temporal = df_temporal.rename(columns={columna: 'Order Cost'})
            df_temporal = df_temporal.reset_index(drop=True)
            # Almacenar el DataFrame resultante en el diccionario
            
            df_name = f'DF_{i}'  # Nombre único para el DataFrame
            dataframes[df_name] = df_temporal
            dataframe_names.append(df_name)  # Agregar el nombre a la lista
            i += 1  # Incrementar el contador

    return dataframes, dataframe_names

# %%
#use the function

dataframes, dataframe_names = generarDfLimpio(df)

# we vertically concatenate all df generated with the function
concatenated_df = pd.concat([dataframes[name][['Order Id', 'Order Cost', 'Segment','Ship Mode']] for name in dataframe_names], axis=0, ignore_index=True)

# %%
concatenated_df.head()
# Out:
#          Order Id Order Cost   Segment    Ship Mode
# 0  CA-2011-103366     149,95  Consumer  First Class
# 1  CA-2011-109043      243,6  Consumer  First Class
# 2  CA-2011-113166      9,568  Consumer  First Class
# 3  CA-2011-124023       8,96  Consumer  First Class
# 4  CA-2011-130155       34,2  Consumer  First Class

# %%
concatenated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order Id    822 non-null    object
#  1   Order Cost  822 non-null    object
#  2   Segment     822 non-null    object
#  3   Ship Mode   822 non-null    object
# dtypes: object(4)
# memory usage: 25.8+ KB

# %%
concatenated_df = concatenated_df.reset_index(drop=True)
concatenated_df['Order Cost'] = concatenated_df['Order Cost'].str.replace(',', '.')
concatenated_df['Order Cost'] = concatenated_df['Order Cost'].astype(float)
concatenated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order Id    822 non-null    object
#  1   Order Cost  822 non-null    float64
#  2   Segment     822 non-null    object
#  3   Ship Mode   822 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 25.8+ KB

# %%
# Make a plot using the seaborn and matplotlib libraries to show the order cost totals
# sorted by shipmode

# Hacemos un gráfico usando la librias seaborn y matplotlib para mostrar los totales de los order cost 
# ordenados por shipmode

# set the size of the chart
# Establecer el tamaño del gráfico
sns.set(rc={'figure.figsize': (12, 6)})

# Create the bar chart without filtering
# Crear el gráfico de barras sin necesidad de filtrar
grafico = sns.barplot(x='Ship Mode', y='Order Cost', data=concatenated_df, estimator=sum)

# Graph Title
# Título del gráfico
grafico.set_title('Total por Categorías de Ship Mode')
# Show Graph
# Mostrar el gráfico
plt.show()
